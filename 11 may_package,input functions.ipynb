# %% [markdown]
# # Packages ,Modlues ,Functions

# %% [markdown]
# x=math.sqrt(25)

# %%
round(x)
# Out:
# 5

# %% [markdown]
# # floor

# %%
math.floor(2.5)
# Out:
# 2

# %%
math.floor(344.10)
# Out:
# 344

# %% [markdown]
# # ceil

# %%
math.ceil(33.5)
# Out:
# 34

# %%
math.ceil(2.3)
# Out:
# 3

# %% [markdown]
# # Import

# %%
import math as n
n.floor(223.5)
# Out:
# 223

# %%
n.ceil(223.5)
# Out:
# 224

# %%
from math import * #multiple tasks will run at ones
print(math.pow(2,3))
print(math.sqrt(40))
print(math.floor(225.5))
print(math.ceil(40.5))
# Out:
# 8.0
# 6.324555320336759
# 225
# 41

# %% [markdown]
# # Help

# %%
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  quit
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  math
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
# ...

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# # Input() function

# %%
x=input() #input function take string not integer
y=input()
z=x+y
print(z)
# Out:
#  2
#  3
# 23

# %%
type(x)
type(y)
type(z)
# Out:
# str

# %%
x=int(input()) #typecasting string to intger
x1=int(input())
x2=x+x1
print(x2)
# Out:
#  2
#  3
# 5

# %%
type(x2)
# Out:
# int

# %%
s=input('enter a string')
print(s)
# Out:
# enter a string mrjai
# mrjai

# %%
print(s[0])
# Out:
# m

# %%
print(s[-3])
# Out:
# j

# %%
print(s[3:-1])
# Out:
# a

# %%
print(s[2:])
# Out:
# jai

# %% [markdown]
# # string with indexing and slicing

# %%
s=input('enter a string')[2:-1]
print(s)
# Out:
# enter a string mrjai
# ja

# %%
s=input('enter a string')[4:]
print(s)
# Out:
# enter a string 123456789
# 56789

# %% [markdown]
# # input() function with eval()

# %%
r=eval(input())
print(r)
# Out:
#  2+3-10
# -5
