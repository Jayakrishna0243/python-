# %% [markdown]
# - list
# - tuple
# - set
# - dict
# - range

# %%
l=[]
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l=[1,2,3,4]
l
# Out:
# [1, 2, 3, 4]

# %%
len(l)
# Out:
# 4

# %% [markdown]
# # append

# %%
l=[10,20,30,40] # adding of new values into the list
l.append(20)
l.append(200)
l.append(2000)
l.append(2)
l.append(22)
l.append(221)
print(l)
# Out:
# [10, 20, 30, 40, 20, 200, 2000, 2, 22, 221]

# %% [markdown]
# # Clear

# %%
l.clear()

# %%
l
# Out:
# []

# %% [markdown]
# # Nested List

# %%
l1=[10, 20, 30, 40, 20, 200, 2000, 2, 22, 221,['a','w']]
l1
# Out:
# [10, 20, 30, 40, 20, 200, 2000, 2, 22, 221, ['a', 'w']]

# %% [markdown]
# # copy

# %%
l1.copy()
# Out:
# [10, 20, 30, 40, 20, 200, 2000, 2, 22, 221, ['a', 'w']]

# %%
l1=l.copy()

# %%
l
# Out:
# []

# %%
l1
# Out:
# []

# %%
# count

# %%
l.count(5.3)
# Out:
# 0

# %%
l=[2,3,4,4,3,4,3]
l.count(4)
# Out:
# 3

# %% [markdown]
# # slicing of list

# %%
l[:]
# Out:
# [2, 3, 4, 4, 3, 4, 3]

# %%
l[-1]
# Out:
# 3

# %%
l[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 l[100]
#
# IndexError: list index out of range

# %%
l[1]
# Out:
# 3

# %%
l[::1]
# Out:
# [2, 3, 4, 4, 3, 4, 3]

# %%
l[::5]
# Out:
# [2, 4]

# %%
l[0::-1]
# Out:
# [2]

# %%
l[::-1]
# Out:
# [3, 4, 3, 4, 4, 3, 2]
